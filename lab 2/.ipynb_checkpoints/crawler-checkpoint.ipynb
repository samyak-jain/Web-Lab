# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
class Crawler():
    def __init__(self, url, max_pages):
        self.url = url
        self.max_pages = max_pages

    def get_url(self, current_url, urls_found):
        urls = set([])
        try:
            response = requests.get(current_url)
        except:
            print('Unable to connect to internet or Invalid link. Please check')
            return urls
        soup = BeautifulSoup(response.text, "lxml")
        for i in soup(['script', 'style']):
            i.extract()
            
        with open(f"temp/{hash(current_url)}.txt", "w") as f:
            f.write(soup.get_text())
            
        newLink = soup.findAll('a')
        for link in newLink:
            try:
                link = str(link.get('href'))
                m = re.match(r'http+', link)
                if not m:
                    link = current_url + link
                if link not in urls_found:
                    urls.add(str(link))
            except UnicodeEncodeError as e:
                print('Error ---> ', e)
        return urls
        
    def start(self, algorithm):
        structure = []
        urls_found = set([])
        structure.append(self.url)
        count = 0
        while count < self.max_pages and structure:
            if algorithm == "bfs":
                current_url = structure.pop(0)
            else:
                current_url = structure.pop()
            urls = self.get_url(current_url, urls_found)
            print('[%s] links found in %s' %(len(urls), current_url))
            for i in urls:
                structure.append(i)
                urls_found.add(i)
            count += 1
        return urls_found
        
    def __str__(self):
        return 'url:%s' % (self.url)

# %%
crawler = Crawler("http://vit.ac.in", 5)

# %%
crawler.start("bfs")
# Out:
# [108] links found in http://vit.ac.in
# [59] links found in http://www.vit.ac.in/admissions/postoffices
# [1] links found in http://www.vit.ac.in/files/wifiservices.pdf
# [7] links found in https://mail.google.com/
# [1] links found in http://vtop2.vit.ac.in:8080/UGNRI/
# {'http://academics2.vit.ac.in/onlinewithdraw/',
#  'http://careers.vit.ac.in/',
#  'http://careers.vit.ac.in/careers/',
#  'http://chennai.vit.ac.in/',
#  'http://gmail.vit.ac.in',
#  'http://info.vit.ac.in/guesthouse',
#  'http://info.vit.ac.in/map/',
#  'http://intranet.vit.ac.in',
#  'http://intranet.vit.ac.in/',
#  'http://vit.ac.in',
#  'http://vit.ac.in http://www.vit.ac.in/files/admissions/Affidavit_Parent.pdf',
#  'http://vit.ac.in#',
#  'http://vit.ac.in/',
#  'http://vit.ac.in/about',
#  'http://vit.ac.in/about/administrativeOffices',
#  'http://vit.ac.in/about/community',
#  'http://vit.ac.in/about/infrastructure',
#  'http://vit.ac.in/about/leadership',
#  'http://vit.ac.in/about/mhrd',
#  'http://vit.ac.in/about/news',
#  'http://vit.ac.in/about/raac',
#  'http://vit.ac.in/about/sustainability',
#  'http://vit.ac.in/academics',
#  'http://vit.ac.in/academics/centers',
#  'http://vit.ac.in/academics/certificates',
#  'http://vit.ac.in/academics/coe',
#  'http://vit.ac.in/academics/ffcs',
#  'http://vit.ac.in/academics/internationalRelations',
#  'http://vit.ac.in/academics/iqac',
#  'http://vit.ac.in/academics/itp',
#  'http://vit.ac.in/academics/library',
#  'http://vit.ac.in/academics/schools',
#  'http://vit.ac.in/academics/transcripts',
#  'http://vit.ac.in/admissions',
#  'http://vit.ac.in/admissions/international',
#  'http://vit.ac.in/admissions/pg',
#  'http://vit.ac.in/admissions/research',
#  'http://vit.ac.in/admissions/ug',
#  'http://vit.ac.in/campus',
#  'http://vit.ac.in/campus/fests',
#  'http://vit.ac.in/campus/healthservices',
#  'http://vit.ac.in/campus/hostels',
#  'http://vit.ac.in/campus/ncc',
#  'http://vit.ac.in/campus/otheramenities',
#  'http://vit.ac.in/campus/sae',
#  'http://vit.ac.in/campus/sports',
#  'http://vit.ac.in/campus/startups',
#  'http://vit.ac.in/campus/studentchapters',
#  'http://vit.ac.in/campus/studentchapters/creationLabs',
#  'http://vit.ac.in/campus/studentclubs',
#  'http://vit.ac.in/contactus',
#  'http://vit.ac.in/events',
#  'http://vit.ac.in/events/eventView/Art Festival 2018',
#  'http://vit.ac.in/events/eventView/Two Day Workshop on Raspberry Pi Programming for Beginners 2018',
#  'http://vit.ac.in/events/eventView/VIT Summer School ',
#  'http://vit.ac.in/files/viteee2017/Hotels_VLR.pdf',
#  'http://vit.ac.in/icc',
#  'http://vit.ac.in/iprcell',
#  'http://vit.ac.in/placement',
#  'http://vit.ac.in/placement/advancedTraining',
#  'http://vit.ac.in/placement/consortium',
#  'http://vit.ac.in/placement/dreamoffers',
#  'http://vit.ac.in/placement/pat',
#  'http://vit.ac.in/redressal',
#  'http://vit.ac.in/research',
#  'http://vit.ac.in/research/academic',
#  'http://vit.ac.in/research/centers',
#  'http://vit.ac.in/research/sponsoredResearch',
#  'http://vit.ac.in/vitunplugged',
#  'http://vit.ac.inNone',
#  'http://vitbhopal.ac.in/',
#  'http://vtop2.vit.ac.in:8080/UGFOREIGN/',
#  'http://vtop2.vit.ac.in:8080/UGNRI/',
#  'http://vtop2.vit.ac.in:8080/UGNRI/register.jsp',
#  'http://vtop2.vit.ac.in:8080/VITEEE/',
#  'http://vtop3.vit.ac.in:8080/VITEEERESULTS/',
#  'http://vtop7.vit.ac.in:8080/paymentfreshers/',
#  'http://www.google.com/support/accounts?hl=en',
#  'http://www.mhrdnats.gov.in/',
#  'http://www.vit.ac.in/admissions/postoffices',
#  'http://www.vit.ac.in/admissions/postoffices http://www.vit.ac.in/files/admissions/Affidavit_Parent.pdf',
#  'http://www.vit.ac.in/admissions/postoffices#',
#  'http://www.vit.ac.in/admissions/postoffices/',
#  'http://www.vit.ac.in/admissions/postoffices/about',
#  'http://www.vit.ac.in/admissions/postoffices/about/administrativeOffices',
#  'http://www.vit.ac.in/admissions/postoffices/about/community',
#  'http://www.vit.ac.in/admissions/postoffices/about/infrastructure',
#  'http://www.vit.ac.in/admissions/postoffices/about/leadership',
#  'http://www.vit.ac.in/admissions/postoffices/about/mhrd',
#  'http://www.vit.ac.in/admissions/postoffices/about/news',
#  'http://www.vit.ac.in/admissions/postoffices/about/raac',
#  'http://www.vit.ac.in/admissions/postoffices/about/sustainability',
#  'http://www.vit.ac.in/admissions/postoffices/academics',
#  'http://www.vit.ac.in/admissions/postoffices/academics/centers',
#  'http://www.vit.ac.in/admissions/postoffices/academics/certificates',
#  'http://www.vit.ac.in/admissions/postoffices/academics/coe',
#  'http://www.vit.ac.in/admissions/postoffices/academics/ffcs',
#  'http://www.vit.ac.in/admissions/postoffices/academics/internationalRelations',
#  'http://www.vit.ac.in/admissions/postoffices/academics/iqac',
#  'http://www.vit.ac.in/admissions/postoffices/academics/itp',
#  'http://www.vit.ac.in/admissions/postoffices/academics/library',
#  'http://www.vit.ac.in/admissions/postoffices/academics/schools',
#  'http://www.vit.ac.in/admissions/postoffices/academics/transcripts',
#  'http://www.vit.ac.in/admissions/postoffices/admissions',
#  'http://www.vit.ac.in/admissions/postoffices/admissions/international',
#  'http://www.vit.ac.in/admissions/postoffices/admissions/pg',
#  'http://www.vit.ac.in/admissions/postoffices/admissions/research',
#  'http://www.vit.ac.in/admissions/postoffices/admissions/ug',
#  'http://www.vit.ac.in/admissions/postoffices/campus',
#  'http://www.vit.ac.in/admissions/postoffices/campus/fests',
#  'http://www.vit.ac.in/admissions/postoffices/campus/healthservices',
#  'http://www.vit.ac.in/admissions/postoffices/campus/hostels',
#  'http://www.vit.ac.in/admissions/postoffices/campus/ncc',
#  'http://www.vit.ac.in/admissions/postoffices/campus/otheramenities',
#  'http://www.vit.ac.in/admissions/postoffices/campus/sae',
#  'http://www.vit.ac.in/admissions/postoffices/campus/sports',
#  'http://www.vit.ac.in/admissions/postoffices/campus/startups',
#  'http://www.vit.ac.in/admissions/postoffices/campus/studentchapters',
#  'http://www.vit.ac.in/admissions/postoffices/campus/studentchapters/creationLabs',
#  'http://www.vit.ac.in/admissions/postoffices/campus/studentclubs',
#  'http://www.vit.ac.in/admissions/postoffices/contactus',
#  'http://www.vit.ac.in/admissions/postoffices/events',
#  'http://www.vit.ac.in/admissions/postoffices/events/eventView/Art Festival 2018',
#  'http://www.vit.ac.in/admissions/postoffices/events/eventView/Two Day Workshop on Raspberry Pi Programming for Beginners 2018',
#  'http://www.vit.ac.in/admissions/postoffices/events/eventView/VIT Summer School ',
#  'http://www.vit.ac.in/admissions/postoffices/icc',
#  'http://www.vit.ac.in/admissions/postoffices/iprcell',
#  'http://www.vit.ac.in/admissions/postoffices/placement',
#  'http://www.vit.ac.in/admissions/postoffices/placement/advancedTraining',
#  'http://www.vit.ac.in/admissions/postoffices/placement/consortium',
#  'http://www.vit.ac.in/admissions/postoffices/placement/dreamoffers',
#  'http://www.vit.ac.in/admissions/postoffices/placement/pat',
#  'http://www.vit.ac.in/admissions/postoffices/redressal',
#  'http://www.vit.ac.in/admissions/postoffices/research',
#  'http://www.vit.ac.in/admissions/postoffices/research/academic',
#  'http://www.vit.ac.in/admissions/postoffices/research/centers',
#  'http://www.vit.ac.in/admissions/postoffices/research/sponsoredResearch',
#  'http://www.vit.ac.in/admissions/postoffices/vitunplugged',
#  'http://www.vit.ac.in/admissions/postofficesNone',
#  'http://www.vit.ac.in/admissions/testcities',
#  'http://www.vit.ac.in/ap',
#  'http://www.vit.ac.in/ap/careers',
#  'http://www.vit.ac.in/btechadmissions/viteee2017',
#  'http://www.vit.ac.in/files/FormatGuidelines.doc',
#  'http://www.vit.ac.in/files/PGAdmissions2018/index.html',
#  'http://www.vit.ac.in/files/SBST_Freshers_App.rar',
#  'http://www.vit.ac.in/files/admissions/Affidavit_Student.pdf',
#  'http://www.vit.ac.in/files/admissions/Hostel_Affidavit_Ladies_2018.pdf',
#  'http://www.vit.ac.in/files/admissions/Hostel_Affidavit_Mens_2018.pdf',
#  'http://www.vit.ac.in/files/admissions/PhysicalFitness_Certificate.pdf',
#  'http://www.vit.ac.in/files/admissions/viteee/VITEEE2018_Biology.pdf',
#  'http://www.vit.ac.in/files/admissions/viteee/VITEEE2018_Chemistry.pdf',
#  'http://www.vit.ac.in/files/admissions/viteee/VITEEE2018_English.pdf',
#  'http://www.vit.ac.in/files/admissions/viteee/VITEEE2018_Mathematics.pdf',
#  'http://www.vit.ac.in/files/admissions/viteee/VITEEE2018_Physics.pdf',
#  'http://www.vit.ac.in/files/hostels/HostelAdmission_InformationSheet.pdf',
#  'http://www.vit.ac.in/files/ug-2018/index.html',
#  'http://www.vit.ac.in/files/wifiservices.pdf',
#  'http://www.vit.ac.in/files/wifiservices.pdfNone',
#  'http://www.vitaa.org/',
#  'http://www.vittbi.com/tedp_food.pdf',
#  'https://academics.vit.ac.in/faculty/fac_login.asp',
#  'https://accounts.google.com/AccountChooser?continue=https%3A%2F%2Fmail.google.com%2Fmail%2F&service=mail&rm=false&ltmpl=default&scc=1&ss=1&osid=1&emr=1',
#  'https://accounts.google.com/SignUp?service=mail&continue=https%3A%2F%2Fmail.google.com%2Fmail%2F&ltmpl=default',
#  'https://accounts.google.com/TOS?loc=IN&hl=en',
#  'https://accounts.google.com/TOS?loc=IN&hl=en&privacy=true',
#  'https://accounts.google.com/signin/usernamerecovery?continue=https%3A%2F%2Fmail.google.com%2Fmail%2F&service=mail&ss=1&scc=1&rm=false&osid=1&hl=en',
#  'https://mail.google.com/',
#  'https://peopleorbit.vit.ac.in/',
#  'https://plus.google.com/107959047122513483934',
#  'https://vtop9.vit.ac.in/vtop/login/freshers',
#  'https://vtopbeta.vit.ac.in/studentprofile/',
#  'https://vtopbeta.vit.ac.in/vtop/',
#  'https://webmail.vit.ac.in',
#  'https://webmail.vit.ac.in/',
#  'https://www.google.com/intl/en/about'}
